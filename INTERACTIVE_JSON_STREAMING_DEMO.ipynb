# %% [markdown]
# # Interactive Table Streaming Demo Using
# # Snowpipe Streaming V2 SDK for Real-Time Data Ingestion
#
# ##### Author: Colm Moynihan
# ##### Date: 3 Feb 2026 - Build in London
#
# ### Overview
# This notebook demonstrates how to ingest JSON data into Snowflake **Interactive Tables** using the **Snowpipe Streaming V2 SDK**. Interactive Tables are optimized for real-time analytics workloads with sub-second query latency.
#
# ### What You'll Learn
#
# | Step | Description |
# |------|-------------|
# | 1️⃣ | Create database, schema, and Interactive Table |
# | 2️⃣ | Generate realistic UK web analytics data as JSON |
# | 3️⃣ | Stream JSON data using Snowpipe Streaming V2 |
# | 4️⃣ | Query and analyze the ingested data |
#
# ### Why Snowpipe Streaming V2?
#
# Interactive Tables have a **critical limitation**: they cannot be populated using standard SQL DML statements.
#
# | Method | Works with Interactive Tables? |
# |--------|-------------------------------|
# | `INSERT INTO` | ❌ No |
# | `COPY INTO` | ❌ No |
# | Regular Snowpipe | ❌ No |
# | **Snowpipe Streaming V2** | ✅ Yes |
# | Kafka Connector | ✅ Yes |
# | Spark Connector (streaming) | ✅ Yes |
#
# ### Prerequisites
#
# ```bash
# pip install snowpipe-streaming
# ```
#
# You also need **key-pair authentication** configured for your Snowflake user.
#
# ---

# %% [markdown]
# ## 🔌 Connect to Snowflake
#
# First, establish a connection to Snowflake using the `colms_uswest` connection profile with key-pair authentication.

# %%
# Cell: connect_to_snowflake
# Establish connection to Snowflake using colms_uswest profile

import os
import snowflake.connector
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.backends import default_backend
from tabulate import tabulate

# ============================================
# CONNECTION CONFIGURATION (colms_uswest)
# ============================================
SNOWFLAKE_ACCOUNT = "SFSEEUROPE-COLM_USWEST"
SNOWFLAKE_USER = "ADMIN"
PRIVATE_KEY_PATH = os.path.expanduser("~/.ssh/snowflake/rsa_key.p8")
DATABASE = "DASH_DB"
SCHEMA = "DASH_SCHEMA"
WAREHOUSE = "COMPUTE_WH"
ROLE = "ACCOUNTADMIN"

# ============================================
# Load Private Key
# ============================================
def load_private_key(path):
    with open(path, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None,
            backend=default_backend()
        )
    return private_key.private_bytes(
        encoding=serialization.Encoding.DER,
        format=serialization.PrivateFormat.PKCS8,
        encryption_algorithm=serialization.NoEncryption()
    )

# ============================================
# Create Connection
# ============================================
print("🔌 Connecting to Snowflake (colms_uswest)...")
print(f"   Account:   {SNOWFLAKE_ACCOUNT}")
print(f"   User:      {SNOWFLAKE_USER}")
print(f"   Role:      {ROLE}")
print(f"   Warehouse: {WAREHOUSE}")

conn = snowflake.connector.connect(
    account=SNOWFLAKE_ACCOUNT,
    user=SNOWFLAKE_USER,
    private_key=load_private_key(PRIVATE_KEY_PATH),
    warehouse=WAREHOUSE,
    role=ROLE,
)

# ============================================
# Helper function to run SQL queries
# ============================================
def run_sql(sql, fetch=True):
    """Execute SQL and optionally return results as a formatted table."""
    cursor = conn.cursor()
    try:
        # Handle multi-statement SQL
        statements = [s.strip() for s in sql.split(';') if s.strip()]
        results = []
        for stmt in statements:
            cursor.execute(stmt)
            if fetch and cursor.description:
                columns = [col[0] for col in cursor.description]
                rows = cursor.fetchall()
                if rows:
                    print(tabulate(rows, headers=columns, tablefmt="pretty"))
                    results.append((columns, rows))
            else:
                print(f"✅ {stmt[:50]}..." if len(stmt) > 50 else f"✅ {stmt}")
        return results
    finally:
        cursor.close()

print("\n✅ Connected to Snowflake successfully!")
print("\n📝 Use run_sql('YOUR SQL HERE') to execute queries.")
# Out:
# 🔌 Connecting to Snowflake (colms_uswest)...
#    Account:   SFSEEUROPE-COLM_USWEST
#    User:      ADMIN
#    Role:      ACCOUNTADMIN
#    Warehouse: COMPUTE_WH
#
# ✅ Connected to Snowflake successfully!
#
# 📝 Use run_sql('YOUR SQL HERE') to execute queries.

# %% [markdown]
# ## 1️⃣ Setup Database & Schema
#
# First, we create a dedicated database and schema to organize our Interactive Table and streaming infrastructure.

# %%
# Cell: setup_database
# Create the database and schema
run_sql("""
CREATE DATABASE IF NOT EXISTS INTERACTIVE_JSON_DB;
USE DATABASE INTERACTIVE_JSON_DB;
CREATE SCHEMA IF NOT EXISTS STREAMING;
USE SCHEMA STREAMING
""")
# Out:
# +----------------------------------------------------------+
# |                          status                          |
# +----------------------------------------------------------+
# | INTERACTIVE_JSON_DB already exists, statement succeeded. |
# +----------------------------------------------------------+
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
# +------------------------------------------------+
# |                     status                     |
# +------------------------------------------------+
# | STREAMING already exists, statement succeeded. |
# +------------------------------------------------+
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
# [(['status'], [('INTERACTIVE_JSON_DB already exists, statement succeeded.',)]),
#  (['status'], [('Statement executed successfully.',)]),
#  (['status'], [('STREAMING already exists, statement succeeded.',)]),
#  (['status'], [('Statement executed successfully.',)])]

# %% [markdown]
# ## 2️⃣ Create Interactive Table
#
# **Interactive Tables** are a Snowflake table type designed for real-time analytics:
#
# | Feature | Description |
# |---------|-------------|
# | **Query Latency** | Sub-second response times |
# | **Data Freshness** | Near real-time data availability |
# | **Clustering** | Automatic micro-partitioning for fast lookups |
# | **Use Case** | Dashboards, operational analytics, real-time reporting |
#
# ### Table Schema
#
# Our `CUSTOMERS` table stores UK web analytics events with the following columns:
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `EVENTDATE` | DATE | Date of the web visit |
# | `COUNTERID` | NUMBER | Unique session counter |
# | `CLIENTIP` | VARCHAR | Visitor's IP address (UK-based) |
# | `SEARCHENGINEID` | NUMBER | Search engine source (1=Google, 2=Bing, etc.) |
# | `SEARCHPHRASE` | VARCHAR | Search query that led to the visit |
# | `RESOLUTIONWIDTH` | NUMBER | Screen resolution width |
# | `TITLE` | VARCHAR | Page title visited |
# | `ISREFRESH` | NUMBER | Whether page was refreshed (0/1) |
# | `DONTCOUNTHITS` | NUMBER | Bot/excluded traffic flag (0/1) |
#
# ⚠️ **Important:** Interactive Tables can ONLY be populated via Snowpipe Streaming SDK!

# %%
# Cell: create_interactive_table
# Create Interactive Table (for Ingest SDK streaming)
run_sql("""
CREATE OR REPLACE INTERACTIVE TABLE CUSTOMERS CLUSTER BY (CLIENTIP) (
    EVENTDATE DATE,
    COUNTERID NUMBER(38,0),
    CLIENTIP VARCHAR(16777216),
    SEARCHENGINEID NUMBER(38,0),
    SEARCHPHRASE VARCHAR(16777216),
    RESOLUTIONWIDTH NUMBER(38,0),
    TITLE VARCHAR(16777216),
    ISREFRESH NUMBER(38,0),
    DONTCOUNTHITS NUMBER(38,0)
)
""")
# Out:
# +---------------------------------------+
# |                status                 |
# +---------------------------------------+
# | Table CUSTOMERS successfully created. |
# +---------------------------------------+
# [(['status'], [('Table CUSTOMERS successfully created.',)])]

# %% [markdown]
# ### Grant Permissions
#
# Grant necessary permissions to allow the streaming role to insert data.

# %%
# Cell: grant_permissions
# Grant necessary permissions for streaming
run_sql("""
GRANT USAGE ON DATABASE INTERACTIVE_JSON_DB TO ROLE ACCOUNTADMIN;
GRANT USAGE ON SCHEMA INTERACTIVE_JSON_DB.STREAMING TO ROLE ACCOUNTADMIN;
GRANT INSERT ON TABLE INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS TO ROLE ACCOUNTADMIN
""")
# Out:
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
# [(['status'], [('Statement executed successfully.',)]),
#  (['status'], [('Statement executed successfully.',)]),
#  (['status'], [('Statement executed successfully.',)])]

# %% [markdown]
# ## 3️⃣ Generate JSON Customer Data
#
# This Python cell generates **500 realistic UK web analytics events** as JSON records. The data simulates:
#
# | Data Element | Description |
# |--------------|-------------|
# | **UK IP Addresses** | IP prefixes mapped to 10 major UK cities |
# | **Search Phrases** | Common UK search queries (NHS, trains, property, etc.) |
# | **Page Titles** | Popular UK websites (BBC, Guardian, Amazon.co.uk, etc.) |
# | **Screen Resolutions** | Common desktop/mobile resolutions |
# | **Date Range** | Events spread across the last 30 days |
#
# The output is a list of **JSON dictionaries** ready for streaming ingestion.

# %%
# Cell: generate_uk_data
import json
import random
from datetime import datetime, timedelta

# UK-specific data
UK_CITIES_IPS = {
    "London": ["185.86.", "194.168.", "212.58.", "31.52."],
    "Manchester": ["81.105.", "82.132.", "109.170.", "86.156."],
    "Birmingham": ["92.233.", "86.149.", "109.157.", "81.103."],
    "Leeds": ["90.216.", "86.146.", "109.154.", "81.108."],
    "Glasgow": ["92.238.", "86.159.", "109.148.", "81.111."],
    "Liverpool": ["81.100.", "86.147.", "109.171.", "90.218."],
    "Bristol": ["86.153.", "109.155.", "81.106.", "92.234."],
    "Edinburgh": ["86.158.", "109.149.", "81.112.", "92.239."],
    "Cardiff": ["86.154.", "109.156.", "81.107.", "92.235."],
    "Belfast": ["86.160.", "109.150.", "81.113.", "92.240."],
}

UK_SEARCH_PHRASES = [
    "best fish and chips near me", "weather forecast london", "premier league results",
    "train times to manchester", "nhs appointment booking", "uk visa requirements",
    "cheap flights heathrow", "rightmove houses for sale", "bbc news live",
    "tesco delivery slots", "argos click and collect", "amazon uk prime",
    "royal mail tracking", "dvla tax check", "energy price cap uk",
]

UK_PAGE_TITLES = [
    "BBC News - Home", "The Guardian | News", "Daily Mail Online",
    "Sky News - Breaking News", "Rightmove - UK Property", "Amazon.co.uk",
    "Tesco Groceries Online", "Sainsbury's Shopping", "Argos | Same Day Delivery",
    "John Lewis & Partners", "NHS Health A-Z", "GOV.UK Services",
]

RESOLUTIONS = [1920, 1366, 1536, 1440, 1280, 2560, 3840, 1680]

def generate_uk_ip():
    city = random.choice(list(UK_CITIES_IPS.keys()))
    prefix = random.choice(UK_CITIES_IPS[city])
    return f"{prefix}{random.randint(1, 254)}.{random.randint(1, 254)}"

def generate_customer_event(event_date):
    return {
        "EVENTDATE": event_date.strftime("%Y-%m-%d"),
        "COUNTERID": random.randint(100000, 999999),
        "CLIENTIP": generate_uk_ip(),
        "SEARCHENGINEID": random.choices([1, 2, 3, 4, 5, 0], weights=[50, 20, 10, 10, 5, 5])[0],
        "SEARCHPHRASE": random.choice(UK_SEARCH_PHRASES) if random.random() > 0.3 else "",
        "RESOLUTIONWIDTH": random.choice(RESOLUTIONS),
        "TITLE": random.choice(UK_PAGE_TITLES),
        "ISREFRESH": random.choices([0, 1], weights=[85, 15])[0],
        "DONTCOUNTHITS": random.choices([0, 1], weights=[95, 5])[0],
    }

# Generate 1,000 records
records = []
base_date = datetime.now()
for _ in range(1000):
    event_date = base_date - timedelta(days=random.randint(0, 30))
    records.append(generate_customer_event(event_date))

print(f"✅ Generated {len(records)} UK customer records")
print("\nSample record:")
print(json.dumps(records[0], indent=2))
# Out:
# ✅ Generated 1000 UK customer records
#
# Sample record:
# {
#   "EVENTDATE": "2026-01-05",
#   "COUNTERID": 509272,
#   "CLIENTIP": "90.218.115.177",
#   "SEARCHENGINEID": 4,
#   "SEARCHPHRASE": "",
#   "RESOLUTIONWIDTH": 2560,
#   "TITLE": "John Lewis & Partners",
#   "ISREFRESH": 0,
#   "DONTCOUNTHITS": 0
# }

# %% [markdown]
# ## 4️⃣ Stream JSON Data via Snowpipe Streaming V2
#
# ### How Snowpipe Streaming V2 Works
#
# Snowpipe Streaming V2 provides **low-latency data ingestion** directly into Snowflake tables:
#
# ```
# ┌─────────────────┐     ┌──────────────────┐     ┌─────────────────────┐
# │  JSON Records   │ ──► │  Streaming SDK   │ ──► │  Interactive Table  │
# │  (Python list)  │     │  (append_row)    │     │  (CUSTOMERS)        │
# └─────────────────┘     └──────────────────┘     └─────────────────────┘
# ```
#
# ### Key Components
#
# | Component | Description |
# |-----------|-------------|
# | **StreamingIngestClient** | Main client that manages the connection to Snowflake |
# | **Channel** | A logical stream for writing data to a specific table |
# | **Default Pipe** | Auto-generated pipe with naming convention `TABLE_NAME-STREAMING` |
# | **append_row()** | Method to insert individual JSON records |
#
# ### Authentication
#
# Snowpipe Streaming V2 requires **key-pair authentication**:
# - Private key file (`.p8` format)
# - Public key registered with your Snowflake user
#
# ### Configuration
#
# | Parameter | Value |
# |-----------|-------|
# | Account | `SFSEEUROPE-COLM_USWEST` |
# | User | `ADMIN` |
# | Role | `ACCOUNTADMIN` |
# | Default Pipe | `CUSTOMERS-STREAMING` |

# %%
# Cell: stream_to_interactive_table
# ============================================
# Snowpipe Streaming V2 - Stream data to Interactive Table
# ============================================
# IMPORTANT: This cell uses the Snowpipe Streaming SDK (V2)
# DO NOT use SQL INSERT - it will fail on Interactive Tables!
# ============================================
import os
# ============================================
# CONFIGURATION - Update these values
# ============================================
SNOWFLAKE_ACCOUNT = "SFSEEUROPE-COLM_USWEST"  
SNOWFLAKE_USER = "ADMIN"
PRIVATE_KEY_PATH = os.path.expanduser("~/.ssh/snowflake/rsa_key.p8")

# Target table details
DATABASE = "INTERACTIVE_JSON_DB"
SCHEMA = "STREAMING"
TABLE = "CUSTOMERS"
ROLE = "ACCOUNTADMIN"

# Default pipe naming convention for Interactive Tables: TABLE_NAME-STREAMING
PIPE_NAME = f"{TABLE}-STREAMING"

# ============================================
# Load Private Key as PEM string
# ============================================
def load_private_key_pem(path):
    with open(path, "rb") as key_file:
        return key_file.read().decode('utf-8')

# ============================================
# Stream Data using Snowpipe Streaming V2 SDK
# ============================================
print("=" * 60)
print("SNOWPIPE STREAMING V2 - Interactive Table Data Ingestion")
print("=" * 60)

# Import the Snowpipe Streaming SDK
from snowflake.ingest.streaming import StreamingIngestClient

# Load private key as PEM string
private_key_pem = load_private_key_pem(PRIVATE_KEY_PATH)

print(f"🔌 Connecting to Snowflake...")
print(f"   Account: {SNOWFLAKE_ACCOUNT}")
print(f"   User: {SNOWFLAKE_USER}")
print(f"   Target: {DATABASE}.{SCHEMA}.{TABLE}")
print(f"   Default Pipe: {PIPE_NAME}")

# Create Snowpipe Streaming V2 client
client = StreamingIngestClient(
    client_name=f"{TABLE}_client",
    db_name=DATABASE,
    schema_name=SCHEMA,
    pipe_name=PIPE_NAME,
    properties={
        "account": SNOWFLAKE_ACCOUNT,
        "user": SNOWFLAKE_USER,
        "private_key": private_key_pem,
        "role": ROLE,
        "url": f"https://{SNOWFLAKE_ACCOUNT}.snowflakecomputing.com"
    }
)

# Open a streaming channel to the Interactive Table
print(f"\n📡 Opening streaming channel...")
channel, status = client.open_channel(f"{TABLE}_channel")
print(f"   Channel status: {status}")

# Stream records using Snowpipe Streaming V2 (NOT SQL INSERT!)
print(f"\n🚀 Streaming {len(records)} records via Snowpipe Streaming V2...")
print("   (Using channel.append_row() - NOT SQL INSERT)")

for i, record in enumerate(records):
    # Use Snowpipe Streaming V2 append_row method
    # This is the ONLY way to insert into Interactive Tables
    channel.append_row(record)
    
    # Progress indicator every 100 records
    if (i + 1) % 100 == 0:
        print(f"   ✓ Streamed {i + 1}/{len(records)} records...")

# Close channel and client properly
print("\n📤 Flushing and closing channel...")
channel.close()
client.close()

print(f"\n" + "=" * 60)
print(f"✅ SUCCESS: Streamed {len(records)} records to Interactive Table")
print(f"   Table: {DATABASE}.{SCHEMA}.{TABLE}")
print(f"   Method: Snowpipe Streaming V2 (append_row)")
print("=" * 60)
# Out:
# ============================================================
# SNOWPIPE STREAMING V2 - Interactive Table Data Ingestion
# ============================================================
# 2026-01-22T16:50:59Z | INFO | core (246) | thread_unknown | Logger initialized with level: INFO
# 2026-01-22T16:50:59Z | INFO | core::util::process_info_provider (130) | thread_unknown | Running in Kubernetes pod: false
# 2026-01-22T16:50:59Z | INFO | core::util::process_info_provider (59) | thread_unknown | Initialized process_info_provider with refresh duration: 50 ms
# 2026-01-22T16:50:59Z | INFO | core (201) | thread_unknown | SDK execution environment initialized: language=python, version=1.1.2, shaded=false, sdk_id=b98c1b11-034d-4b05-9b0d-168d5122bac1
# 2026-01-22T16:50:59Z | INFO | core::prod::metrics (87) | thread_unknown | Telemetry exporter initialized without Prometheus recorder
# 🔌 Connecting to Snowflake...
#    Account: SFSEEUROPE-COLM_USWEST
#    User: ADMIN
#    Target: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS
#    Default Pipe: CUSTOMERS-STREAMING
# 2026-01-22T16:50:59Z | INFO | core::prod::security::jwt (157) | thread_unknown | Creating JWTManager with account: SFSEEUROPE-COLM_USWEST, user: ADMIN, role: ACCOUNTADMIN
#
# 📡 Opening streaming channel...
# 2026-01-22T16:50:59Z | INFO | core::prod::security::jwt (218) | thread_unknown | JWTManager created with account: SFSEEUROPE-COLM_USWEST, user: ADMIN
# 2026-01-22T16:51:00Z | INFO | core::prod::ingest_client (248) | thread_unknown | Retrieved account subdomain hostname: HEB26349.ingest.pdxaaj.snowflakecomputing.com
# 2026-01-22T16:51:00Z | INFO | core::prod::security::scoped (87) | thread_unknown | Creating ScopedTokenManager with client_identifier: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client, account_url: https://SFSEEUROPE-COLM-USWEST.snowflakecomputing.com, subdomain_name: HEB26349.ingest.pdxaaj.snowflakecomputing.com, original auth manager: KEYPAIR_JWT
# 2026-01-22T16:51:00Z | INFO | core::prod::security::scoped (339) | thread_unknown | ScopedTokenManager: extracted JWT token expiration - expires in 3599s (Unix timestamp: 1769104260) for client=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:00Z | INFO | core::prod::security::scoped (131) | thread_unknown | ScopedTokenManager successfully created.
# 2026-01-22T16:51:00Z | INFO | core::prod::sf_client::sf_mgmt_client (59) | thread_unknown | ManagementClient backoff policy: ExponentialBackoff { initial_backoff: 1s, backoff_multiplier: 2, max_backoff: 60s, total_backoff: 7200s, jitter_ratio: 0.5 }
# 2026-01-22T16:51:00Z | INFO | core::prod::metrics::telemetry_service (94) | thread_unknown | Starting Telemetry Service for client: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:00Z | INFO | core::prod::sf_client::sf_mgmt_client (111) | thread_unknown | Fetch pipe info for INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:01Z | INFO | core::prod::sf_client::pipe_info_manager (298) | thread_unknown | PipeInfoManager: pipe info expires at 1769104261000, required refresh duration=3599.029s, next refresh_duration=3539.029s
# 2026-01-22T16:51:02Z | INFO | core::prod::channel_status_cache (305) | sf | Starting channel status cache background refresh task for client INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:02Z | INFO | core::prod::ingest_client (624) | thread_unknown | Open channel from INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client for channel_name = CUSTOMERS_channel, offset_token =
#    Channel status: Channel 'CUSTOMERS_channel': SUCCESS
#
# 🚀 Streaming 1000 records via Snowpipe Streaming V2...
#    (Using channel.append_row() - NOT SQL INSERT)
#    ✓ Streamed 100/1000 records...
#    ✓ Streamed 200/1000 records...
#    ✓ Streamed 300/1000 records...
#    ✓ Streamed 400/1000 records...
#    ✓ Streamed 500/1000 records...
#    ✓ Streamed 600/1000 records...
#    ✓ Streamed 700/1000 records...
#    ✓ Streamed 800/1000 records...
#    ✓ Streamed 900/1000 records...
#    ✓ Streamed 1000/1000 records...
#
# 📤 Flushing and closing channel...
# 2026-01-22T16:51:02Z | INFO | core::prod::channel (588) | thread_unknown | Channel INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel is closed, drop=false, wait_for_flush=true
# 2026-01-22T16:51:02Z | INFO | core::prod::channel::data_processor (417) | sf | DataProcessor: input_control received a kick on the control channel for INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel
# 2026-01-22T16:51:02Z | INFO | core::prod::channel::data_processor (357) | sf | DataProcessor: Starting to process dequeued data for INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel batch_bytes=209978 approx_input_data_bytes_inflight=0 flush_mode_estimated=Inline flush_mode_final=Inline
# 2026-01-22T16:51:02Z | WARN | core::prod::channel::data_processor (624) | sf | DataProcessor.try_send: backpressure: waiting to send data to snowflake-informer. channel=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel
# 2026-01-22T16:51:03Z | INFO | core::prod::channel (532) | thread_unknown | Flush completed successfully for channel INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel
# 2026-01-22T16:51:03Z | INFO | core::prod::channel (597) | thread_unknown | Channel INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel is flushed successfully.
# 2026-01-22T16:51:03Z | INFO | core::prod::channel::data_processor (210) | thread_unknown | DataProcessor.shutdown: cancelling tokio task. channel=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel
# 2026-01-22T16:51:03Z | INFO | core::prod::channel::data_processor (214) | thread_unknown | DataProcessor.shutdown: shutdown tokio task. channel=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel
# 2026-01-22T16:51:03Z | INFO | core::prod::channel::snowflake_informer (205) | thread_unknown | SnowflakeInformer.shutdown: cancelling tokio task. channel=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel
# 2026-01-22T16:51:03Z | INFO | core::prod::channel::snowflake_informer (209) | thread_unknown | SnowflakeInformer.shutdown: shutdown tokio task. channel=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel
# 2026-01-22T16:51:03Z | INFO | core::prod::channel (631) | thread_unknown | Channel INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client.CUSTOMERS_channel successfully closed and removed from map
# 2026-01-22T16:51:03Z | INFO | core::prod::ingest_client (727) | thread_unknown | Closing client INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client with wait_for_flush=true, timeout=None
# 2026-01-22T16:51:03Z | INFO | core::prod::metrics::telemetry_service (242) | thread_unknown | Flush and Shutdown: Initiating graceful shutdown for client: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:03Z | INFO | core::prod::metrics::telemetry_service (167) | sf | Received shutdown signal, performing final flush for client: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:03Z | INFO | core::prod::metrics::telemetry_service (191) | sf | Telemetry Service periodic task shutting down for client: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:03Z | INFO | core::prod::metrics::telemetry_service (262) | thread_unknown | Flush and Shutdown: Graceful shutdown completed for client: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:03Z | INFO | core::prod::security::scoped (420) | thread_unknown | ScopedTokenManager.shutdown: cancelling tokio task. client=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:03Z | INFO | core::prod::security::scoped (424) | thread_unknown | ScopedTokenManager.shutdown: shutdown tokio task. client=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
#
# ============================================================
# ✅ SUCCESS: Streamed 1000 records to Interactive Table
#    Table: INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS
#    Method: Snowpipe Streaming V2 (append_row)
# ============================================================
# 2026-01-22T16:51:03Z | INFO | core::prod::sf_client::pipe_info_manager (321) | thread_unknown | PipeInfoManager.shutdown: shutdown tokio task. client=INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS-STREAMING.CUSTOMERS_client
# 2026-01-22T16:51:03Z | INFO | core::prod::channel_status_cache (432) | thread_unknown | shutdown: shutdown tokio task

# %% [markdown]
# ## 5️⃣ Verify Data & Run Analytics
#
# Now that the data has been streamed into the Interactive Table, let's verify the ingestion and run some analytics queries.
#
# ### Verification Queries
#
# The following queries demonstrate the **sub-second query latency** of Interactive Tables:

# %%
# Cell: setup_interactive_warehouse
# Create and configure Interactive Warehouse for sub-second queries
print("="*60)
print("⚡ SETTING UP INTERACTIVE WAREHOUSE")
print("="*60)

# Create Interactive Warehouse
run_sql("CREATE OR REPLACE INTERACTIVE WAREHOUSE INTERACTIVE_WH_IOT WAREHOUSE_SIZE = 'XSMALL'")

# Add the Interactive Table to the warehouse
run_sql("ALTER WAREHOUSE INTERACTIVE_WH_IOT ADD TABLES (INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS)")

# Resume the warehouse
run_sql("ALTER WAREHOUSE INTERACTIVE_WH_IOT RESUME IF SUSPENDED")

# Use the Interactive Warehouse
run_sql("USE WAREHOUSE INTERACTIVE_WH_IOT")

print()
print("✅ Interactive Warehouse ready for sub-second queries!")
# Out:
# ============================================================
# ⚡ SETTING UP INTERACTIVE WAREHOUSE
# ============================================================
# +----------------------------------------------------------------+
# |                             status                             |
# +----------------------------------------------------------------+
# | INTERACTIVE WAREHOUSE INTERACTIVE_WH_IOT successfully created. |
# +----------------------------------------------------------------+
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
# +----------------------------------+
# |              status              |
# +----------------------------------+
# | Statement executed successfully. |
# +----------------------------------+
#
# ✅ Interactive Warehouse ready for sub-second queries!

# %% [markdown]
# ## 6️⃣ View Streaming Ingestion History & Logs
#
# The Snowpipe Streaming SDK generates logs both **client-side** (in the notebook output) and **server-side** (in Snowflake system views).
#
# ### Client-Side Logs
# The SDK logs appear in the cell output with entries like:
# - `core::channel::flusher` - Channel flush operations
# - `core::util::process_info_provider` - Memory/CPU telemetry
# - `core::prod::security::scoped` - JWT token management
# - `core::prod::ingest_client` - Client connection events
#
# ### Server-Side Logs (ACCOUNT_USAGE Views)
# Snowflake tracks streaming ingestion in these system views (note: **~2 hour data latency**):
#
# | View | Purpose |
# |------|---------|
# | `SNOWPIPE_STREAMING_CHANNEL_HISTORY` | Channel-level metrics: rows inserted, parsed, errors |
# | `SNOWPIPE_STREAMING_CLIENT_HISTORY` | Client-level events: blob sizes, event types |
# | `PIPE_USAGE_HISTORY` | Pipe usage: credits, bytes inserted/billed |
# | `PIPES` | Pipe definitions and metadata |
#
# ### Real-Time Monitoring
# - `SHOW PIPES` - View active streaming pipes (immediate)

# %%
# Cell: verify_data_count
# ============================================
# Verify Data in Interactive Table (Real-time)
# ============================================
print("=" * 60)
print("✅ DATA VERIFICATION (Real-time)")
print("=" * 60)

run_sql("""
SELECT 
    COUNT(*) AS TOTAL_RECORDS,
    MIN(EVENTDATE) AS EARLIEST_EVENT,
    MAX(EVENTDATE) AS LATEST_EVENT
FROM INTERACTIVE_JSON_DB.STREAMING.CUSTOMERS
""")
# Out:
# ============================================================
# ✅ DATA VERIFICATION (Real-time)
# ============================================================
# +---------------+----------------+--------------+
# | TOTAL_RECORDS | EARLIEST_EVENT | LATEST_EVENT |
# +---------------+----------------+--------------+
# |       0       |                |              |
# +---------------+----------------+--------------+
# [(['TOTAL_RECORDS', 'EARLIEST_EVENT', 'LATEST_EVENT'], [(0, None, None)])]
# 2026-01-22T16:51:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35561947136, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2850397, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T16:52:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35607085056, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.22700243, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T16:53:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35526328320, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.18838863, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T16:54:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35501096960, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2508814, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T16:55:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154042368, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35402645504, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.239297, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T16:56:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154042368, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35480764416, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.225, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T16:57:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154042368, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35446095872, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.23714454, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T16:58:59Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35488448512, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3023463, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:00:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35460661248, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.22996412, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:01:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35445751808, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.37413862, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:02:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35451584512, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.29867065, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:03:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35494068224, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.25955883, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:04:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421557157888, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35571171328, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3314303, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:05:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35457515520, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4089372, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:06:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35377627136, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2752003, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:07:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35350036480, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.24806067, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:08:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35480748032, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2236246, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:09:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35402399744, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.31095973, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:10:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35494838272, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2114929, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:11:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35394207744, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.44653755, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:12:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421557157888, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35494428672, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.40102202, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:13:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35409510400, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.21938325, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:14:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35622027264, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4850629, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:15:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421557157888, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35453616128, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.23054907, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:16:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35512303616, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.20600729, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:17:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421557157888, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35391356928, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.31726477, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:18:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35430727680, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2280061, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:19:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35422093312, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.257815, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:20:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35411542016, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.37344256, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:21:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35366862848, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.20914297, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:22:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35461578752, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.18998016, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:23:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35330686976, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3714314, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:24:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35164864512, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3181082, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:25:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35368861696, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.490669, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:26:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35372105728, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.20422427, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:27:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35380838400, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4771816, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:28:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35347447808, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.26369616, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:29:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35343941632, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.5530411, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:30:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35420487680, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.34825397, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:31:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35326951424, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.21568741, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:32:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35527376896, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2707536, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:33:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35523280896, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2968254, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:34:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35595124736, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.48830646, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:35:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35391963136, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.234375, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:36:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35419308032, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.26633722, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:37:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35509731328, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.44618544, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:38:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35434053632, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4322275, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:39:00Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35333259264, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2533527, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:40:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35527049216, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3916471, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:41:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35462823936, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.46837303, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:42:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35350691840, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.45529225, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:43:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154075136, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35503996928, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4533412, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:44:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35460857856, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.35462964, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:45:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35534012416, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3004937, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:46:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35506700288, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.30292258, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:47:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35448750080, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.20107655, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:48:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154091520, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35548053504, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.45197472, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:49:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35500736512, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.41911873, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:50:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35553591296, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.47203746, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:51:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35377823744, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.32095125, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:52:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35993468928, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.23478682, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:53:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35614932992, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.20326954, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:54:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35429761024, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.22092979, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:55:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35473276928, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2735646, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:56:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35543302144, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.19319445, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:57:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35658366976, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4432558, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:58:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35817472000, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.27097425, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T17:59:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35439771648, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.52906555, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:00:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35492790272, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.35620993, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:01:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35357409280, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.24535257, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:02:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154107904, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35649847296, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4785047, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:03:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35152625664, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.31184107, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:04:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35169992704, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.27584913, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:05:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35178414080, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.39314517, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:06:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35221225472, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.28958333, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:07:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35196862464, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.42686045, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:08:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35235266560, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.42640844, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:09:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35249307648, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.25566745, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:10:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35173285888, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.5096899, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:11:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35242016768, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.24192096, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:12:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35259662336, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.38317683, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:13:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35240837120, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.50784427, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:14:01Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35325886464, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.37652582, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:15:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154124288, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35362701312, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.41059524, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:16:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35384049664, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.5147831, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:17:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35329982464, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.30103192, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:18:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35388325888, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.5474374, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:19:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35387555840, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4304382, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:20:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35427270656, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4108487, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:21:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154157056, process_total_memory_bytes: 421557157888, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35424550912, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.30733025, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:22:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35376103424, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.44649842, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:23:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35469623296, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4139341, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:24:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35319791616, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.305873, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:25:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35393994752, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.41148326, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:26:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35321053184, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3174224, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:27:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35322970112, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.46504304, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:28:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35285712896, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.21998063, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:29:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35494248448, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.315669, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:30:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35611312128, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.28025275, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:31:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35452911616, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4606612, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:32:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35498688512, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.5068287, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:33:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35561832448, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.36760125, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:34:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35575398400, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.27367842, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:35:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35741286400, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2367091, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:36:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35626074112, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.1657188, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:37:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35547660288, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.434886, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:38:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35628892160, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3616942, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:39:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35613097984, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.5163008, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:40:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36004380672, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.34676147, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:41:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35772481536, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.24015997, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:42:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35867246592, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.27987063, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:43:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154157056, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35818143744, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.41830987, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:44:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154157056, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35898523648, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4982752, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:45:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154157056, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36019191808, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.41367128, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:46:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154157056, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35957882880, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.41666666, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:47:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35908452352, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.214554, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-22T18:48:02Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154140672, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35807674368, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.45630953, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# ...
# 2026-01-23T08:26:24Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35870785536, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.20854953, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:27:24Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35959767040, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.23742138, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:28:24Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35878731776, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.0953594, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:29:24Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35890561024, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.23628144, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:30:24Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35905306624, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.24946934, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:31:24Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35896246272, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2188244, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:32:24Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35863199744, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.25538522, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:33:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35798581248, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.24078746, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:34:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35825713152, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.30544257, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:35:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36074078208, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.23861882, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:36:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35786948608, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4870413, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:37:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35974627328, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.29213616, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:38:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35926474752, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.32704365, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:39:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35856547840, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.40572917, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:40:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36089692160, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.46567369, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:41:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35914629120, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2682752, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:42:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 35993911296, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3255814, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:43:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154206208, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36027678720, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.31179246, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:44:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154206208, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36044455936, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.28052923, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:45:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154206208, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36021862400, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.30996886, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:46:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 36009820160, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.25931603, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:47:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31977078784, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.23042071, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:48:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 29250060288, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.22027512, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:49:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 29388455936, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.37622663, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:50:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 29533880320, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.45839256, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:51:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 30546837504, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.35240915, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:52:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 30497177600, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.43101415, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:53:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154206208, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 30447452160, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.30459502, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:54:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154206208, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 30596431872, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.51261735, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:55:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 30903697408, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.5818287, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:56:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31198773248, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.47197327, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:57:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31179194368, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.2599374, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:58:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31228428288, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.44748017, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T08:59:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31500713984, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.22089174, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T09:00:25Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31909462016, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4747038, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T09:01:26Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31348277248, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.3505332, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T09:02:26Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31391809536, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.52134144, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T09:03:26Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31396560896, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.44454226, num_workers: 10, num_tasks: 2, queue_depth: 0 }
# 2026-01-23T09:04:26Z | INFO | core::util::process_info_provider (174) | sf | Current process info: ProcessInfo { process_used_memory_bytes: 154189824, process_total_memory_bytes: 421556584448, pod_used_memory_bytes: 0, pod_total_memory_bytes: 0, system_used_memory_bytes: 31565037568, system_total_memory_bytes: 68719476736, cpu_usage_percent: 0.4680296, num_workers: 10, num_tasks: 2, queue_depth: 0 }

# %% [markdown]
# ---
#
# ## 📋 Summary
#
# This notebook demonstrates streaming data directly into an **Interactive Table** using the Snowpipe Streaming SDK.
#
# | Object | Name | Purpose |
# |--------|------|---------|
# | Database | `INTERACTIVE_JSON_DB` | Container for streaming demo |
# | Interactive Table | `CUSTOMERS` | Real-time analytics with sub-second latency |
# | Default Pipe | `CUSTOMERS-STREAMING` | System-generated pipe for streaming |
#
# ### Key Points:
#
# ⚠️ **Interactive Tables can ONLY be populated via:**
# - Snowpipe Streaming SDK (this notebook)
# - Snowflake Kafka Connector
# - Snowflake Spark Connector (streaming mode)
#
# ❌ **These do NOT work with Interactive Tables:**
# - SQL `INSERT` statements
# - `COPY INTO` commands
# - Regular Snowpipe
#
# # Generate keypair for authentication
# ### To stream more data:
# Simply run the Python cells again with new records - the Streaming SDK will stream them directly to the Interactive Table!

# %% [markdown]
# ---
#
# **End of Notebook**
